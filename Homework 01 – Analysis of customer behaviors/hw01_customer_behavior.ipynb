# %% [markdown]
# # BADS7105 - Homework 1 : Analysis of Customer Behavior

# %% [markdown]
# ## Step 1 : Import Library

# %%
import pandas as pd
import numpy as np
from kmodes.kmodes import KModes
import re

# %% [markdown]
# ## Step 2 : Data Preparation

# %% [markdown]
# ### Get data to DataFrame

# %%
cust_beh = pd.read_excel("./Customer Behaviors (Responses).xlsx")

# %%
cust_beh.reset_index(inplace=True)

# %%
cust_beh.columns
# Out:
# Index(['index', 'Timestamp',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารสุขภาพ]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ชาบูชาบู]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ปิ้งย่าง]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เสื้อผ้าแฟชั่น]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [แต่งหน้า]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [skincare บำรุงผิว]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การออกกำลังกาย]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเล่นเกมส์]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การท่องเที่ยว]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านหนังสือ]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านบทความ Online]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเรียน e-learning]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Series]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดูหนัง]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Youtube]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Netflix]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content ด้านบันเทิง]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่่ยวกับเกมส์]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการ review ร้านอาหาร]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการท่องเที่ยว]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการแต่งบ้าน]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการโทรทัศน์]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับละคร]',
#        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการเมือง]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารญี่ปุ่น]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารจึน]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารไทย]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารอีสาน]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารสุขภาพ]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [บุฟเฟต์]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ชาบูชาบู]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ปิ้งย่าง]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เหล้าเบียร์]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เสื้อผ้าแฟชั่น]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [แต่งหน้า]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [skincare บำรุงผิว]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การออกกำลังกาย]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเล่นเกมส์]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การท่องเที่ยว]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านหนังสือ]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านบทความ Online]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเรียน e-learning]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Series]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดูหนัง]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Youtube]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Netflix]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content ด้านบันเทิง]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่่ยวกับเกมส์]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการ review ร้านอาหาร]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการท่องเที่ยว]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการแต่งบ้าน]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการโทรทัศน์]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับละคร]',
#        'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการเมือง]',
#        'นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง',
#        'คุณเกิดวันที่เท่าไหร่', 'เพศ'],
#       dtype='object')

# %% [markdown]
# ### Create Customer Interest Dataframe

# %%
cust_beh_irs = cust_beh[['index',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารสุขภาพ]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ชาบูชาบู]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ปิ้งย่าง]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เสื้อผ้าแฟชั่น]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [แต่งหน้า]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [skincare บำรุงผิว]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การออกกำลังกาย]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเล่นเกมส์]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การท่องเที่ยว]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านหนังสือ]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านบทความ Online]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเรียน e-learning]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Series]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดูหนัง]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Youtube]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Netflix]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content ด้านบันเทิง]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่่ยวกับเกมส์]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการ review ร้านอาหาร]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการท่องเที่ยว]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการแต่งบ้าน]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการโทรทัศน์]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับละคร]',
        'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการเมือง]']]

# %% [markdown]
# ### Create Customer Consume DataFrame

# %%
cust_beh_con = cust_beh[['index',
    'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารญี่ปุ่น]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารจึน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารไทย]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารอีสาน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารสุขภาพ]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [บุฟเฟต์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ชาบูชาบู]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ปิ้งย่าง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เหล้าเบียร์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เสื้อผ้าแฟชั่น]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [แต่งหน้า]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [skincare บำรุงผิว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การออกกำลังกาย]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเล่นเกมส์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การท่องเที่ยว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านหนังสือ]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านบทความ Online]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเรียน e-learning]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Series]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดูหนัง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Youtube]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Netflix]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content ด้านบันเทิง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่่ยวกับเกมส์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการ review ร้านอาหาร]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการท่องเที่ยว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการแต่งบ้าน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการโทรทัศน์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับละคร]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการเมือง]']]

# %% [markdown]
# ### Create Customer Other Interesting DataFrame

# %%
cust_beh_oth = cust_beh[['index','นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง']]

# %% [markdown]
# ### Create Customer Demographic DataFrame

# %%
cust_beh_dem = cust_beh[['index',
       'คุณเกิดวันที่เท่าไหร่', 'เพศ']]

# %% [markdown]
# ### Clean Customer Interest & Customer Consume Columns name

# %%
cust_beh_irs_col = [re.search(r'\[(.+)\]', text).group(1) if re.search(r'\[(.+)\]', text) != None else text for text in cust_beh_irs.columns]
cust_beh_con_col = [re.search(r'\[(.+)\]', text).group(1) if re.search(r'\[(.+)\]', text) != None else text for text in cust_beh_con.columns]

# %%
cust_beh_irs.columns = cust_beh_irs_col
cust_beh_con.columns = cust_beh_con_col

# %%
cust_beh_irs_m = cust_beh_irs.melt(['index'])
cust_beh_con_m = cust_beh_con.melt(['index'])

# %% [markdown]
# ### Clean Birth date in Customer Demographic

# %%
# def new_year(i):
#     if i.year > 2400:
#         i = i.replace(year = i.year -543)
#     else:
#         i
#     return i
# cust_beh_dem['คุณเกิดวันที่เท่าไหร่'] = cust_beh_dem['คุณเกิดวันที่เท่าไหร่'].apply(new_year)

# %% [markdown]
# ### Export data to csv files for Dashboard

# %%
# cust_beh_dem.to_csv('./customer_behavior_demographic.csv')
# cust_beh_irs_m.to_csv('./customer_behavior_interest.csv')
# cust_beh_con_m.to_csv('./customer_behavior_consume.csv')
# cust_beh_oth.to_csv('./customer_behavior_other.csv')

# %% [markdown]
# ### Convert Level to Score

# %%
dum_irs = dict(zip(['สนใจอย่างมากที่สุด','สนใจอย่างมาก','สนใจ','เฉยๆ','ไม่สนใจ','ไม่สนใจอย่างมาก','ไม่สนใจอย่างมากที่สุด'],[7,6,5,4,3,2,1]))

# %%
dum_con = dict(zip(['แทบทุกวัน','อาทิตย์ละครั้ง','เดือนละ 2-3 ครั้ง','เดือนละครั้ง','หลายเดือนครั้ง','แทบไม่ได้บริโภคเลย'],[6,5,4,3,2,1]))

# %%
cust_beh_clus = cust_beh[['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารสุขภาพ]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ชาบูชาบู]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ปิ้งย่าง]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เสื้อผ้าแฟชั่น]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [แต่งหน้า]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [skincare บำรุงผิว]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การออกกำลังกาย]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเล่นเกมส์]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การท่องเที่ยว]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านหนังสือ]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การอ่านบทความ Online]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [การเรียน e-learning]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Series]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดูหนัง]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Youtube]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ดู Netflix]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content ด้านบันเทิง]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่่ยวกับเกมส์]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการ review ร้านอาหาร]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการท่องเที่ยว]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการแต่งบ้าน]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการโทรทัศน์]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับละคร]',
       'คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [Content เกี่ยวกับการเมือง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารญี่ปุ่น]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารจึน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารไทย]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารอีสาน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [อาหารสุขภาพ]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [บุฟเฟต์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ชาบูชาบู]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ปิ้งย่าง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เหล้าเบียร์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [เสื้อผ้าแฟชั่น]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [แต่งหน้า]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [skincare บำรุงผิว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การออกกำลังกาย]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเล่นเกมส์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การท่องเที่ยว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านหนังสือ]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การอ่านบทความ Online]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [การเรียน e-learning]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Series]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดูหนัง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Youtube]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [ดู Netflix]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content ด้านบันเทิง]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่่ยวกับเกมส์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการ review ร้านอาหาร]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการท่องเที่ยว]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการแต่งบ้าน]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการโทรทัศน์]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับละคร]',
       'คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการเมือง]']]

# %%
cust_beh_clus.replace(dum_irs,inplace=True)

# %%
cust_beh_clus.replace(dum_con,inplace=True)

# %% [markdown]
# ### Using KMode to cluster customer

# %%
km = KModes(n_clusters=3, init='Huang', n_init=10, verbose=1)

# %%
clusters = km.fit_predict(cust_beh_clus)

# Print the cluster centroids
print(km.labels_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 11, cost: 2225.0
# Run 1, iteration: 2/100, moves: 5, cost: 2203.0
# Run 1, iteration: 3/100, moves: 1, cost: 2200.0
# Run 1, iteration: 4/100, moves: 0, cost: 2200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 5, cost: 2241.0
# Run 2, iteration: 2/100, moves: 0, cost: 2241.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 4, cost: 2248.0
# Run 3, iteration: 2/100, moves: 2, cost: 2240.0
# Run 3, iteration: 3/100, moves: 0, cost: 2240.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 4, cost: 2235.0
# Run 4, iteration: 2/100, moves: 3, cost: 2226.0
# Run 4, iteration: 3/100, moves: 0, cost: 2226.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 5, cost: 2255.0
# Run 5, iteration: 2/100, moves: 1, cost: 2250.0
# Run 5, iteration: 3/100, moves: 1, cost: 2249.0
# Run 5, iteration: 4/100, moves: 0, cost: 2249.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 10, cost: 2217.0
# Run 6, iteration: 2/100, moves: 2, cost: 2206.0
# Run 6, iteration: 3/100, moves: 0, cost: 2206.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 8, cost: 2218.0
# Run 7, iteration: 2/100, moves: 4, cost: 2205.0
# Run 7, iteration: 3/100, moves: 0, cost: 2205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 9, cost: 2223.0
# Run 8, iteration: 2/100, moves: 1, cost: 2224.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 3, cost: 2252.0
# Run 9, iteration: 2/100, moves: 0, cost: 2252.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 7, cost: 2261.0
# Run 10, iteration: 2/100, moves: 0, cost: 2261.0
# Best run was number 1
# [0 2 2 1 0 2 0 0 1 0 2 0 2 2 1 0 0 2 0 2 1 2 1 0 2 1 0 0 1 1 2 2 2 2 0 2 0
#  0 2 0 0 1 0 1 1 0 2 1 0 0 0 0 1 1 2 0 2 0 2 2 0 2 1]

# %%
cust_beh_clus['cluster'] = km.labels_

# %%
cust_beh_clus_f = cust_beh_clus[['cluster']]

# %%
cust_beh_clus_f.reset_index(inplace=True)

# %%
cust_beh_clus_f.to_csv('./customer_behavior_cluster.csv',index=False)
